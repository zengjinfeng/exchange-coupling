# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import pylab as plt

# %% [markdown]
# ## exchange parameter

# %%
BaCr2As2_J_constant = pd.read_csv('./BaCr2As2/BaCr2As2_J_constant.txt', sep=' ', names=['J1', 'J2', 'Jc'])
BaCr2As2_J_constant['r']=BaCr2As2_J_constant['J2']/BaCr2As2_J_constant['J1']
BaCr2As2_J_constant
# Out:
#       J1     J2    Jc         r
# 0  36.66 -27.12  2.92 -0.739771
# 1  42.22 -25.70  3.92 -0.608716
# 2  46.72 -23.03  1.83 -0.492937
# 3  48.91 -20.63  0.21 -0.421795
# 4  49.76 -19.23 -1.38 -0.386455
# 5  40.24 -23.54 -3.07 -0.584990
# 6  31.01 -28.00 -4.77 -0.902935
# 7  22.67 -32.21 -6.44 -1.420820

# %%
BaMn2As2_J_constant = pd.read_csv('./BaMn2As2/BaMn2As2_J_constant.txt', sep=' ', names=['J1', 'J2', 'Jc'])
BaMn2As2_J_constant
# Out:
#        J1     J2    Jc
# 0   95.63  14.55  6.78
# 1   99.17  18.43  6.78
# 2  100.49  21.12  6.49
# 3  100.12  22.82  6.11
# 4   98.08  23.50  5.72
# 5   92.66  22.32  5.34
# 6   87.14  20.93  4.96
# 7   81.61  19.39  4.61

# %%
BaFe2As2_J_constant = pd.read_csv('./BaFe2As2/BaFe2As2_J_constant.txt', sep=' ', names=['J1', 'J2', 'Jc'])
#r_CaFe2P2_J_constant['x']=r_CaFe2P2_J_constant['J2']/r_CaFe2P2_J_constant['J1']
#r_CaFe2P2_J_constant['y']=r_CaFe2P2_J_constant['J3']/r_CaFe2P2_J_constant['J1']
BaFe2As2_J_constant
# Out:
#       J1     J2    Jc
# 0  31.39  33.51  2.19
# 1  25.42  37.49  2.86
# 2  17.78  43.42  3.02
# 3  12.81  50.00  2.82
# 4   8.41  57.69  2.62
# 5  29.45  57.66  2.81
# 6  35.37  60.46  3.18
# 7  38.06  61.35  3.59

# %%
BaCo2As2_J_constant = pd.read_csv('./BaCo2As2/BaCo2As2_J_constant.txt', sep=' ', names=['J1', 'J2', 'Jc'])
BaCo2As2_J_constant
# Out:
#       J1     J2    Jc
# 0  -3.43   0.27  0.54
# 1  -5.48   1.51  0.79
# 2  -8.00   3.91  1.07
# 3  -9.60   7.29  1.17
# 4  -4.57   9.49  1.06
# 5   5.30  12.12  1.12
# 6  17.09  34.09  3.73
# 7  29.94  54.60  3.62

# %%
all_J2_constant = BaCr2As2_J_constant.drop(['J1','J2','Jc','r'], axis=1)
all_J2_constant['BaCr2As2_J2'] = BaCr2As2_J_constant['J2']
all_J2_constant['BaMn2As2_J2'] = BaMn2As2_J_constant['J2']
all_J2_constant['BaFe2As2_J2'] = BaFe2As2_J_constant['J2']
all_J2_constant['BaCo2As2_J2'] = BaCo2As2_J_constant['J2']
all_J2_constant
# Out:
#    BaCr2As2_J2  BaMn2As2_J2  BaFe2As2_J2  BaCo2As2_J2
# 0       -27.12        14.55        33.51         0.27
# 1       -25.70        18.43        37.49         1.51
# 2       -23.03        21.12        43.42         3.91
# 3       -20.63        22.82        50.00         7.29
# 4       -19.23        23.50        57.69         9.49
# 5       -23.54        22.32        57.66        12.12
# 6       -28.00        20.93        60.46        34.09
# 7       -32.21        19.39        61.35        54.60

# %%
all_J2_constant_T = all_J2_constant.T
all_J2_constant_T['x'] = np.arange(4)
all_J2_constant_T
# Out:
#                  0      1      2      3      4      5      6      7  x
# BaCr2As2_J2 -27.12 -25.70 -23.03 -20.63 -19.23 -23.54 -28.00 -32.21  0
# BaMn2As2_J2  14.55  18.43  21.12  22.82  23.50  22.32  20.93  19.39  1
# BaFe2As2_J2  33.51  37.49  43.42  50.00  57.69  57.66  60.46  61.35  2
# BaCo2As2_J2   0.27   1.51   3.91   7.29   9.49  12.12  34.09  54.60  3

# %%
all_J2_constant_T.plot( y=[0,1,2,3,4,5,6,7],kind='line')
plt.legend(('u=0', 'u=0.5', 'u=1','u=1.5','u=2','u=2.5','u=3','u=3.5'),loc=2)

# %%
BaFe2P2_J_constant = pd.read_csv('./BaFe2P2/BaFe2P2_J_constant.txt', sep=' ', names=['J1', 'J2', 'Jc'])
BaFe2P2_J_constant
# Out:
#       J1     J2    Jc
# 0  -0.06   1.23  0.12
# 1   1.74   7.25 -0.31
# 2  50.29  37.78 -0.05
# 3  50.01  44.52  0.13
# 4  43.40  50.45  0.53
# 5  39.30  55.50  0.80
# 6  31.88  63.13  0.94
# 7  44.90  60.19  1.29

# %%
Fe_J2_constant = BaFe2As2_J_constant.drop(['J1','J2','Jc'], axis=1)
Fe_J2_constant['BaFe2P2_J2'] = BaFe2P2_J_constant['J2']
Fe_J2_constant['BaFe2As2_J2'] = BaFe2As2_J_constant['J2']
Fe_J2_constant
# Out:
#    BaFe2P2_J2  BaFe2As2_J2
# 0        1.23        33.51
# 1        7.25        37.49
# 2       37.78        43.42
# 3       44.52        50.00
# 4       50.45        57.69
# 5       55.50        57.66
# 6       63.13        60.46
# 7       60.19        61.35

# %%
Fe_J2_constant_T = Fe_J2_constant.T
Fe_J2_constant_T
# Out:
#                  0      1      2      3      4      5      6      7
# BaFe2P2_J2    1.23   7.25  37.78  44.52  50.45  55.50  63.13  60.19
# BaFe2As2_J2  33.51  37.49  43.42  50.00  57.69  57.66  60.46  61.35

# %%
Fe_J2_constant_T.plot( y=[0,1,2,3,4,5,6,7],kind='line')
plt.legend(('u=0', 'u=0.5', 'u=1','u=1.5','u=2','u=2.5','u=3','u=3.5'),loc=4)

# %% [markdown]
# ## Moment

# %%
BaCr2As2_moment = pd.read_csv('./BaCr2As2/BaCr2As2_moment.txt', sep='\t', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
f = lambda x: x.max() - x.min()
delta = BaCr2As2_moment.apply(f, axis=1)
delta_df = pd.DataFrame(delta)
BaCr2As2_moment['delta_moment'] = delta_df[0]
BaCr2As2_moment
# Out:
#     1_FM  2_GType  3_StripyFM  4_StripyAF  delta_moment
# 0  2.040    2.415       2.251       2.307         0.375
# 1  2.477    2.679       2.658       2.622         0.202
# 2  2.766    2.902       2.923       2.887         0.157
# 3  3.036    3.095       3.108       3.069         0.072
# 4  3.209    3.255       3.256       3.218         0.047
# 5  3.640    3.389       3.382       3.343         0.297
# 6  3.742    3.507       3.494       3.457         0.285
# 7  3.826    3.610       3.594       3.561         0.265

# %%
BaMn2As2_moment = pd.read_csv('./BaMn2As2/BaMn2As2_moment.txt', sep='\t', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
f = lambda x: x.max() - x.min()
delta = BaMn2As2_moment.apply(f, axis=1)
delta_df = pd.DataFrame(delta)
BaMn2As2_moment['delta_moment']=delta_df[0]
BaMn2As2_moment
# Out:
#     1_FM  2_GType  3_StripyFM  4_StripyAF  delta_moment
# 0  3.372    3.505       3.546       3.550         0.178
# 1  3.559    3.641       3.687       3.685         0.128
# 2  3.736    3.757       3.799       3.796         0.063
# 3  3.871    3.856       3.895       3.891         0.039
# 4  4.025    3.943       3.978       3.974         0.082
# 5  4.127    4.020       4.051       4.047         0.107
# 6  4.199    4.088       4.117       4.112         0.111
# 7  4.258    4.150       4.175       4.172         0.108

# %%
BaFe2As2_moment = pd.read_csv('./BaFe2As2/BaFe2As2_moment.txt', sep='\t', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
f = lambda x: x.max() - x.min()
delta = BaFe2As2_moment.apply(f, axis=1)
delta_df = pd.DataFrame(delta)
BaFe2As2_moment['delta_moment'] = delta_df[0]
BaFe2As2_moment
# Out:
#     1_FM  2_GType  3_StripyFM  4_StripyAF  delta_moment
# 0  1.906    1.842       2.036       2.056         0.214
# 1  2.282    2.113       2.308       2.321         0.208
# 2  2.476    2.320       2.535       2.544         0.224
# 3  2.604    2.486       2.689       2.695         0.209
# 4  2.740    2.699       2.802       2.809         0.110
# 5  2.922    2.796       2.895       2.900         0.126
# 6  3.052    2.871       2.972       2.975         0.181
# 7  3.133    2.933       3.037       3.038         0.200

# %%
BaCo2As2_moment = pd.read_csv('./BaCo2As2/BaCo2As2_moment.txt', sep='\t', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
f = lambda x: x.max() - x.min()
delta = BaCo2As2_moment.apply(f, axis=1)
delta_df = pd.DataFrame(delta)
BaCo2As2_moment['delta_moment'] = delta_df[0]
BaCo2As2_moment
# Out:
#     1_FM  2_GType  3_StripyFM  4_StripyAF  delta_moment
# 0  0.408    0.000       0.431       0.471         0.471
# 1  0.478    0.000       0.602       0.630         0.630
# 2  0.546    0.067       0.787       0.806         0.739
# 3  0.617    0.735       0.978       0.985         0.368
# 4  0.675    1.071       1.154       1.160         0.485
# 5  0.738    1.256       1.307       1.332         0.594
# 6  0.812    1.388       1.640       1.660         0.848
# 7  1.413    1.474       1.716       1.729         0.316

# %%
BaFe2P2_moment = pd.read_csv('./BaFe2P2/BaFe2P2_moment.txt', sep='\t', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
f = lambda x: x.max() - x.min()
delta = BaFe2P2_moment.apply(f, axis=1)
delta_df = pd.DataFrame(delta)
BaFe2P2_moment['delta_moment'] = delta_df[0]
BaFe2P2_moment
# Out:
#     1_FM  2_GType  3_StripyFM  4_StripyAF  delta_moment
# 0  0.000    0.002       0.686       0.703         0.703
# 1  0.001    0.944       1.413       1.404         1.412
# 2  1.671    1.546       1.839       1.858         0.312
# 3  2.015    1.894       2.143       2.147         0.253
# 4  2.337    2.135       2.381       2.394         0.259
# 5  2.468    2.347       2.547       2.555         0.208
# 6  2.594    2.504       2.672       2.678         0.174
# 7  2.723    2.645       2.774       2.780         0.135

# %% [markdown]
# ## energy

# %%
BaCr2As2_energy = pd.read_csv('./BaCr2As2/BaCr2As2_energy.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaCr2As2_energy
# Out:
#        1_FM   2_GType  3_StripyFM  4_StripyAF
# 0 -129.9135 -131.1334   -129.6322   -129.6790
# 1 -126.1466 -127.5605   -125.9999   -126.0627
# 2 -122.7204 -124.2445   -122.7308   -122.7600
# 3 -119.5929 -121.1613   -119.7151   -119.7185
# 4 -116.7253 -118.2955   -116.9060   -116.8839
# 5 -114.3831 -115.6217   -114.2735   -114.2244
# 6 -112.1972 -113.1133   -111.7975   -111.7212
# 7 -110.1322 -110.7545   -109.4641   -109.3611

# %%
BaMn2As2_energy = pd.read_csv('./BaMn2As2/BaMn2As2_energy.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaMn2As2_energy
# Out:
#        1_FM   2_GType  3_StripyFM  4_StripyAF
# 0 -127.2384 -130.4073   -129.2343   -129.3428
# 1 -124.6901 -127.9719   -126.8664   -126.9749
# 2 -122.3989 -125.7184   -124.6828   -124.7865
# 3 -120.3234 -123.6250   -122.6555   -122.7533
# 4 -118.4439 -121.6741   -120.7654   -120.8569
# 5 -116.8009 -119.8513   -118.9977   -119.0831
# 6 -115.2767 -118.1447   -117.3408   -117.4202
# 7 -113.8590 -116.5442   -115.7851   -115.8589

# %%
BaFe2As2_energy = pd.read_csv('./BaFe2As2/BaFe2As2_energy.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaFe2As2_energy
# Out:
#        1_FM   2_GType  3_StripyFM  4_StripyAF
# 0 -121.0814 -122.1208   -122.6560   -122.6910
# 1 -117.4405 -118.2996   -119.0470   -119.0927
# 2 -114.0665 -114.6838   -115.7403   -115.7887
# 3 -110.8791 -111.3340   -112.6840   -112.7291
# 4 -107.8456 -108.1565   -109.8261   -109.8680
# 5 -104.8165 -105.8037   -107.1329   -107.1778
# 6 -102.0869 -103.2697   -104.5874   -104.6383
# 7  -99.6057 -100.8811   -102.1778   -102.2352

# %%
BaCo2As2_energy = pd.read_csv('./BaCo2As2/BaCo2As2_energy.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaCo2As2_energy
# Out:
#        1_FM   2_GType  3_StripyFM  4_StripyAF
# 0 -113.9443 -113.8434   -113.8980   -113.9068
# 1 -110.2235 -110.0608   -110.1843   -110.1968
# 2 -106.5388 -106.2999   -106.5359   -106.5531
# 3 -102.8947 -102.6064   -102.9745   -102.9933
# 4  -99.2963  -99.1669    -99.5268    -99.5438
# 5  -95.7456  -95.9331    -96.2182    -96.2361
# 6  -92.2548  -92.8614    -93.6193    -93.6790
# 7  -88.8753  -89.8911    -91.1016    -91.1594

# %%
BaFe2P2_energy = pd.read_csv('./BaFe2P2/BaFe2P2_energy.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaFe2P2_energy
# Out:
#        1_FM   2_GType  3_StripyFM  4_StripyAF
# 0 -133.2723 -133.2723   -133.3106   -133.3125
# 1 -128.7539 -128.8046   -129.0136   -129.0087
# 2 -123.0216 -124.6302   -125.0354   -125.0346
# 3 -119.1215 -120.7240   -121.3462   -121.3483
# 4 -115.6510 -117.0481   -117.9596   -117.9681
# 5 -112.4081 -113.6786   -114.8130   -114.8258
# 6 -109.3328 -110.3680   -111.8631   -111.8782
# 7 -106.4383 -107.8957   -109.0827   -109.1034

# %% [markdown]
# ## Gap

# %%
e_SrMn2As2_gap = pd.read_csv('./gap_SrMn2As2/all_gap.txt', sep='\s+', names=['gap'])
#e_SrMn2As2_gap

# %%
e_CaMn2Sb2_gap = pd.read_csv('./gap_CaMn2Sb2/all_gap.txt', sep='\s+', names=['gap'])
#e_CaMn2Sb2_gap

# %% [markdown]
# ## energy gate

# %%
BaCr2As2_energy_gate = pd.read_csv('./BaCr2As2/BaCr2As2_energy_gate.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaCr2As2_energy_gate
# Out:
#     1_FM  2_GType  3_StripyFM  4_StripyAF
# 0  176.0  -1043.9       457.3       410.6
# 1  295.8  -1118.1       442.5       379.8
# 2  393.6  -1130.6       383.1       353.9
# 3  454.1  -1114.3       331.8       328.5
# 4  477.3  -1092.8       296.7       318.7
# 5  242.6   -996.0       352.1       401.3
# 6   10.1   -906.0       409.8       486.1
# 7 -204.2   -826.5       463.9       566.9

# %%
BaMn2As2_energy_gate = pd.read_csv('./BaMn2As2/BaMn2As2_energy_gate.txt', sep='\s+',names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaMn2As2_energy_gate
# Out:
#      1_FM  2_GType  3_StripyFM  4_StripyAF
# 0  1817.3  -1351.6      -178.6      -287.1
# 1  1935.7  -1346.1      -240.6      -349.1
# 2  1997.8  -1321.8      -286.1      -389.9
# 3  2015.9  -1285.7      -316.2      -414.0
# 4  1991.1  -1239.0      -330.3      -421.8
# 5  1882.3  -1168.1      -314.5      -399.8
# 6  1768.9  -1099.1      -295.2      -374.6
# 7  1652.8  -1032.4      -273.3      -347.1

# %%
BaFe2As2_energy_gate = pd.read_csv('./BaFe2As2/BaFe2As2_energy_gate.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaFe2As2_energy_gate
# Out:
#      1_FM  2_GType  3_StripyFM  4_StripyAF
# 0  1055.9     16.5      -518.7      -553.7
# 1  1029.5    170.3      -577.0      -622.8
# 2  1003.3    386.1      -670.5      -718.8
# 3  1027.4    572.6      -777.4      -822.5
# 4  1078.5    767.5      -902.0      -944.0
# 5  1416.2    429.0      -900.2      -945.1
# 6  1558.7    375.9      -941.8      -992.7
# 7  1619.2    343.9      -952.9     -1010.2

# %%
BaCo2As2_energy_gate = pd.read_csv('./BaCo2As2/BaCo2As2_energy_gate.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaCo2As2_energy_gate
# Out:
#      1_FM  2_GType  3_StripyFM  4_StripyAF
# 0   -46.2     54.7         0.1        -8.6
# 1   -57.1    105.6       -17.9       -30.5
# 2   -56.8    182.0       -54.0       -71.2
# 3   -27.5    260.8      -107.3      -126.1
# 4    87.1    216.5      -143.4      -160.3
# 5   287.7    100.1      -184.9      -202.8
# 6   848.8    242.2      -515.7      -575.3
# 7  1381.6    365.7      -844.7      -902.6

# %%
BaFe2P2_energy_gate = pd.read_csv('./BaFe2P2/BaFe2P2_energy_gate.txt', sep='\s+', names=['1_FM', '2_GType', '3_StripyFM','4_StripyAF'])
BaFe2P2_energy_gate
# Out:
#      1_FM  2_GType  3_StripyFM  4_StripyAF
# 0    19.6     19.6       -18.7       -20.6
# 1   141.3     90.6      -118.4      -113.5
# 2  1408.8   -199.8      -605.0      -604.1
# 3  1513.5    -89.0      -711.2      -713.3
# 4  1505.7    108.6      -802.9      -811.4
# 5  1523.2    252.8      -881.6      -894.4
# 6  1527.7    492.5     -1002.6     -1017.7
# 7  1691.7    234.3      -952.7      -973.3
